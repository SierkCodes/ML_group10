# %%
import numpy as np
import pandas
import sklearn 
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from mlxtend.plotting import plot_decision_regions
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn import datasets
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
#import the data
data = pandas.read_csv('./Project.csv', delimiter=',')

# %%
#print the data
data
# Out:
#       user_id day_type  work_hours  screen_time_hours  meetings_count  \
# 0           1  Weekday        9.59              11.86               4
# 1           1  Weekend        7.38              10.33               4
# 2           1  Weekend        6.31               8.92               1
# 3           1  Weekday        8.34              10.70               4
# 4           1  Weekend        6.97               9.83               1
# ...       ...      ...         ...                ...             ...
# 1795      180  Weekend        6.33               8.16               0
# 1796      180  Weekend        4.70               7.88               0
# 1797      180  Weekend        3.92               6.39               2
# 1798      180  Weekday        8.93              11.11               2
# 1799      180  Weekend        4.38               6.72               0
#
#       breaks_taken  after_hours_work  sleep_hours  task_completion_rate  \
# 0                2                 0         7.55                  91.2
# 1                1                 0         6.69                  82.0
# 2                2                 0         8.87                  80.6
# 3                1                 1         8.13                  70.0
# 4                2                 0         5.85                  67.1
# ...            ...               ...          ...                   ...
# 1795             4                 0         5.59                  73.5
# 1796             4                 0         6.69                  89.8
# 1797             1                 0         6.77                  74.6
# 1798             5                 0         8.28                  74.6
# 1799             1                 0         7.13                  70.7
#
#       burnout_score burnout_risk
# 0             19.17          Low
# 1             29.70          Low
# 2             32.93          Low
# 3             45.47          Low
# 4             51.61          Low
# ...             ...          ...
# 1795          31.91          Low
# 1796          26.30          Low
# 1797          34.07          Low
# 1798          38.14          Low
# 1799          40.76          Low
#
# [1800 rows x 11 columns]

# %%
#set variables
hours_worked = data["work_hours"]
screen_time = data["screen_time_hours"]
meetings_count = data["meetings_count"]
breaks_taken = data["breaks_taken"]
after_hours_work = data["after_hours_work"]
sleep_hours = data["sleep_hours"]
task_completion = data["task_completion_rate"]
burnout_score = data["burnout_score"]
burnout_risk = data["burnout_risk"]

# %%
x = data.drop(columns = ['user_id','burnout_score'])
y = data['burnout_score']

# %%
x_nominal = pandas.get_dummies(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=500)
xn_train, xn_test, yn_train, yn_test = train_test_split(x_nominal, y, test_size=500)

labels = ['model'] + x_nominal.columns.to_list()
labels
spearman_table = pandas.DataFrame(columns = labels)
spearman_table
# Out:
# Empty DataFrame
# Columns: [model, work_hours, screen_time_hours, meetings_count, breaks_taken, after_hours_work, sleep_hours, task_completion_rate, day_type_Weekday, day_type_Weekend, burnout_risk_High, burnout_risk_Low, burnout_risk_Medium]
# Index: []

# %% [markdown]
# ## Linear

# %% [markdown]
# ### Linear Regression

# %%
linear = LinearRegression()

# %%
linear.fit(xn_train, yn_train)
y_predicted_lr = linear.predict(xn_test)
mean_squared_error(yn_test, y_predicted_lr)
# Out:
# 31.725310665156883

# %%
y_predicted_lr = pandas.DataFrame(y_predicted_lr)

# %%
vals = {}
vals['model'] = 'linear regression'

for i in x_nominal.columns:
    vals[i] = x_nominal[i].corr(y_predicted_lr, method='spearman')

spearman_table = pandas.concat([spearman_table, pandas.DataFrame([vals])])
# Out:
# C:\Users\tijee\AppData\Local\Temp\ipykernel_22248\426421780.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   spearman_table = pandas.concat([spearman_table, pandas.DataFrame([vals])])

# %% [markdown]
# ### Ridge Regression

# %%
#create ridge pipeline
ridge_model = Pipeline([
    ('scaler', StandardScaler()),
    ('ridge', Ridge(alpha=1.0)) #alpha 1 is default, we can tune it if necessary
])

# %%
#train the model
ridge_model.fit(xn_train, yn_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('ridge', Ridge())])

# %%
#evaluate
y_pred = ridge_model.predict(xn_test)

print("R2 Score:", r2_score(yn_test, y_pred))
print("MSE:", mean_squared_error(yn_test, y_pred))
# Out:
# R2 Score: 0.9394964551732564
# MSE: 31.7235050443142

# %%
#feature importance
#get coefficients
coefficients = ridge_model.named_steps['ridge'].coef_

#take absolute value (importance magnitude)
importance = np.abs(coefficients)

#create dataframe
ridge_importance = pandas.DataFrame({
    'feature': xn_train.columns,
    'importance': importance
})

#sort by importance
ridge_importance = ridge_importance.sort_values(by='importance', ascending=False)

ridge_importance
# Out:
#                  feature  importance
# 6   task_completion_rate   20.443085
# 9      burnout_risk_High    3.170438
# 10      burnout_risk_Low    1.934416
# 11   burnout_risk_Medium    1.073483
# 1      screen_time_hours    0.766157
# 0             work_hours    0.517012
# 4       after_hours_work    0.242057
# 5            sleep_hours    0.070876
# 7       day_type_Weekday    0.064104
# 8       day_type_Weekend    0.064104
# 3           breaks_taken    0.041464
# 2         meetings_count    0.014595

# %%
#convert to ranking
ridge_importance['rank'] = ridge_importance['importance'].rank(ascending=False)

ridge_importance
# Out:
#                  feature  importance  rank
# 6   task_completion_rate   20.443085   1.0
# 9      burnout_risk_High    3.170438   2.0
# 10      burnout_risk_Low    1.934416   3.0
# 11   burnout_risk_Medium    1.073483   4.0
# 1      screen_time_hours    0.766157   5.0
# 0             work_hours    0.517012   6.0
# 4       after_hours_work    0.242057   7.0
# 5            sleep_hours    0.070876   8.0
# 7       day_type_Weekday    0.064104   9.0
# 8       day_type_Weekend    0.064104  10.0
# 3           breaks_taken    0.041464  11.0
# 2         meetings_count    0.014595  12.0

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Regression Tree

# %%
tree = DecisionTreeRegressor()
parameters_tree = {# 'criterion':('squared_error','friedman_mse','absolute_error','poisson'),
                   'max_depth':[5,10,15,20],
                   'min_samples_split':[5,10,15,20],
                   'max_leaf_nodes':[5,10,20,50,None]
                  }
clf = GridSearchCV(tree, parameters_tree)
clf.fit(xn_train, yn_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [5, 10, 15, 20],
#                          'max_leaf_nodes': [5, 10, 20, 50, None],
#                          'min_samples_split': [5, 10, 15, 20]})

# %%
y_predicted_rt = pandas.DataFrame(clf.predict(xn_test))

vals = {}
vals['model'] = 'regression tree'

for i in x_nominal.columns:
    vals[i] = x_nominal[i].corr(y_predicted_rt, method='spearman')
    
spearman_table = pandas.concat([spearman_table, pandas.DataFrame([vals])])

# %%
spearman_table
# Out:
#                model  work_hours  screen_time_hours  meetings_count  \
# 0  linear regression    0.051020           0.045967        0.052451
# 0    regression tree    0.051236           0.046904        0.049846
#
#    breaks_taken  after_hours_work  sleep_hours  task_completion_rate  \
# 0      0.042554          0.013221    -0.048154             -0.012844
# 0      0.039452          0.013041    -0.056946             -0.014357
#
#    day_type_Weekday  day_type_Weekend  burnout_risk_High  burnout_risk_Low  \
# 0          0.076230         -0.076230          -0.024232         -0.025017
# 0          0.075593         -0.075593          -0.020219         -0.026271
#
#    burnout_risk_Medium
# 0             0.035216
# 0             0.035035

# %%
x_nominal.columns
# Out:
# Index(['work_hours', 'screen_time_hours', 'meetings_count', 'breaks_taken',
#        'after_hours_work', 'sleep_hours', 'task_completion_rate',
#        'day_type_Weekday', 'day_type_Weekend', 'burnout_risk_High',
#        'burnout_risk_Low', 'burnout_risk_Medium'],
#       dtype='object')

# %% [markdown]
# ### Random Forest

# %%
rf_reg = RandomForestRegressor(
    n_estimators=100,
    max_depth=None,
    random_state=42
)
rf_reg.fit(xn_train, yn_train)
y_pred_rf = pandas.DataFrame(rf_reg.predict(xn_test))

vals = {}
vals['model'] = 'random forest'

for i in x_nominal.columns:
    vals[i] = x_nominal[i].corr(y_pred_rf, method='spearman')
    
spearman_table = pandas.concat([spearman_table, pandas.DataFrame([vals])])

# %% [markdown]
# ## Boosting

# %% [markdown]
# ### Gradient Boosting

# %%
gb_reg = GradientBoostingRegressor(
    n_estimators=100,
    max_depth=3,
    random_state=42
)
gb_reg.fit(xn_train, yn_train)
y_pred_gb = pandas.DataFrame(gb_reg.predict(xn_test))

vals = {}
vals['model'] = 'gradient boosting'

for i in x_nominal.columns:
    vals[i] = x_nominal[i].corr(y_pred_gb, method='spearman')

# %%
spearman_table = pandas.concat([spearman_table, pandas.DataFrame([vals])])
spearman_table
# Out:
#                model  work_hours  screen_time_hours  meetings_count  \
# 0  linear regression    0.051020           0.045967        0.052451
# 0    regression tree    0.051236           0.046904        0.049846
# 0      random forest    0.055552           0.047637        0.052013
# 0  gradient boosting    0.052838           0.047398        0.052037
#
#    breaks_taken  after_hours_work  sleep_hours  task_completion_rate  \
# 0      0.042554          0.013221    -0.048154             -0.012844
# 0      0.039452          0.013041    -0.056946             -0.014357
# 0      0.043105          0.021959    -0.051144             -0.014812
# 0      0.042252          0.014658    -0.054485             -0.013904
#
#    day_type_Weekday  day_type_Weekend  burnout_risk_High  burnout_risk_Low  \
# 0          0.076230         -0.076230          -0.024232         -0.025017
# 0          0.075593         -0.075593          -0.020219         -0.026271
# 0          0.080969         -0.080969          -0.019646         -0.033467
# 0          0.078807         -0.078807          -0.023606         -0.027834
#
#    burnout_risk_Medium
# 0             0.035216
# 0             0.035035
# 0             0.042357
# 0             0.037933

# %% [markdown]
# ### XGBoost

# %%
#create the model
xgb_model = XGBRegressor(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=4,
    random_state=42
)
# these search parameters are default/safe and can be altered

# %%
#train the model
xgb_model.fit(xn_train, yn_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
#evaluate performance
y_pred_xgb = xgb_model.predict(xn_test)

print("R2 Score:", r2_score(yn_test, y_pred_xgb))
print("MSE:", mean_squared_error(yn_test, y_pred_xgb))
# Out:
# R2 Score: 0.9405843379683627
# MSE: 31.153101187201347

# %%
#XGBoost handles feature importance in different ways. For research we use "gain" which refers to the average gain of splits.
importance_dict = xgb_model.get_booster().get_score(importance_type='gain')

# %%
#create dataframe with all features
xgb_importance = pandas.DataFrame({
    'feature': xn_train.columns
})

#map gain scores
xgb_importance['importance'] = xgb_importance['feature'].map(importance_dict)

#replace missing values (unused features) with 0
xgb_importance['importance'] = xgb_importance['importance'].fillna(0)

#sort
xgb_importance = xgb_importance.sort_values(by='importance', ascending=False)

xgb_importance
# Out:
#                  feature    importance
# 10      burnout_risk_Low  12575.711914
# 6   task_completion_rate   8743.124023
# 9      burnout_risk_High    610.808167
# 7       day_type_Weekday    135.294357
# 1      screen_time_hours     71.330673
# 0             work_hours     64.455528
# 5            sleep_hours     51.962212
# 4       after_hours_work     49.122250
# 2         meetings_count     44.908707
# 3           breaks_taken     41.905445
# 8       day_type_Weekend      0.000000
# 11   burnout_risk_Medium      0.000000

# %%
#convert to spearman ranking
xgb_importance['rank'] = xgb_importance['importance'].rank(ascending=False)

xgb_importance
# Out:
#                  feature    importance  rank
# 10      burnout_risk_Low  12575.711914   1.0
# 6   task_completion_rate   8743.124023   2.0
# 9      burnout_risk_High    610.808167   3.0
# 7       day_type_Weekday    135.294357   4.0
# 1      screen_time_hours     71.330673   5.0
# 0             work_hours     64.455528   6.0
# 5            sleep_hours     51.962212   7.0
# 4       after_hours_work     49.122250   8.0
# 2         meetings_count     44.908707   9.0
# 3           breaks_taken     41.905445  10.0
# 8       day_type_Weekend      0.000000  11.5
# 11   burnout_risk_Medium      0.000000  11.5

# %%
spearman_table = spearman_table.set_index('model')

# %%
spearman_table.T
# Out:
# model                 linear regression  regression tree  random forest  \
# work_hours                     0.051020         0.051236       0.055552
# screen_time_hours              0.045967         0.046904       0.047637
# meetings_count                 0.052451         0.049846       0.052013
# breaks_taken                   0.042554         0.039452       0.043105
# after_hours_work               0.013221         0.013041       0.021959
# sleep_hours                   -0.048154        -0.056946      -0.051144
# task_completion_rate          -0.012844        -0.014357      -0.014812
# day_type_Weekday               0.076230         0.075593       0.080969
# day_type_Weekend              -0.076230        -0.075593      -0.080969
# burnout_risk_High             -0.024232        -0.020219      -0.019646
# burnout_risk_Low              -0.025017        -0.026271      -0.033467
# burnout_risk_Medium            0.035216         0.035035       0.042357
#
# model                 gradient boosting
# work_hours                     0.052838
# screen_time_hours              0.047398
# meetings_count                 0.052037
# breaks_taken                   0.042252
# after_hours_work               0.014658
# sleep_hours                   -0.054485
# task_completion_rate          -0.013904
# day_type_Weekday               0.078807
# day_type_Weekend              -0.078807
# burnout_risk_High             -0.023606
# burnout_risk_Low              -0.027834
# burnout_risk_Medium            0.037933

# %%
sns.heatmap(spearman_table.T, annot = True, linewidth = 0.5,
            cmap = sns.color_palette("vlag", as_cmap=True),
            vmin = -0.1, vmax = 0.1)
# Out:
# <Axes: xlabel='model'>
